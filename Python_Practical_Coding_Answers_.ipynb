# %% [markdown]
# Python Practical Answers

# %% [markdown]
# 1.	Write a Python program to print "Hello, World!”
# -	print("Hello World")
#
# 2.	Write a Python program that displays your name and age.
# - Age = input(“Enter you age = “)
#   Name = input(“Enter your name = “)
#   print(“my name is name = ”,  and I am  “Age = “ years old”)
#
# 3.	Write code to print all the pre-defined keywords in Python using the keyword library.
# - all_keywords = keyword.kwlist
#        print("The list of pre-defined keywords in Python are:")
#        print(all_keywords)
#
# 4.	Write a program that checks if a given word is a Python keyword.
# - import keyword
#        s = input("enter any word")if keyword.iskeyword(s):
#        print("Your entered word is a given keyword in Python")
#        else:
#        print("Your entered word is not a given keyword in Python")
#
# 5.	Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
# - In Python, lists and tuples both store collections of data, but differ in mutability,
# Lists are mutable, allowing modifications while tuples are immutable, which do not allow any modification.
#  The below program demonstrates how list and tuples are created in Python:
#      my_list = ['apple', 'banana', 'cherry']
#             my_tuple = (10, 20, 30)
#             print(f"Original List: {my_list}")
#             print(f"Original Tuple: {my_tuple}")
#
#             Below is the output of the above program:
#             Original List: ['apple', 'banana', 'cherry']
#             Original Tuple: (10, 20, 30)
#
#        So if want make any changes in my_list then we can do it but in my_tuples we will not be
#        able to do it as it is immutable.  Below mentioned is the example for both.
#
#       Such as if we make any changes in my_list in the above program, the input & output
#       will be:
#             # Change the first element of the list
#
#              my_list[0] = 'orange'
#              print(f"\nModified List: {my_list}")
#
#            # Output: Modified List: ['orange', 'banana', 'cherry']
#
#     And if we make any changes in my_list in the above program, the input & output
#     will be:
#       # Change the first element of the tuple
#
#     my_tuple[0] = 5
#     print(f"\nModified tuple: {my_tuple}")
#
#     # Output: TypeError: 'tuple' object does not support item assignment.
#
# 6.	Write a function to demonstrate the behavior of mutable and immutable arguments.
# 7.	Write a program that performs basic arithmetic operations on two user-input numbers
# -	def arithmetic_calculator():
#         print("Welcome to the basic arithmetic calculator!")
#         print("Enter two numbers and an operator (+, -, *, /).")
#         num1 = float(input("Enter the first number: "))
#         num2 = float(input("Enter the second number: "))
#         operator = input("Enter an operator (+, -, *, /): ")
#         if operator == '+':
#             result = num1 + num2
#         print(f"Result: {num1} + {num2} = {result}")
#        elif operator == '-':
#            result = num1 - num2
#         print(f"Result: {num1} - {num2} = {result}")
#        elif operator == '*':
#           result = num1 * num2
#         print(f"Result: {num1} * {num2} = {result}")
#        elif operator == '/':
#             result = num1 / num2
#             print(f"Result: {num1} / {num2} = {result}")
#        else:
#         print("Invalid operator. Please use +, -, *, or /.")
#        if __name__ == "__main__":
#              arithmetic_calculator()
#
# 8.	Write a program to demonstrate the use of logical operators.
# - age = 25
#   has_license = True
# if age >= 18 and has_license:
#     print(f"Age is {age} and has_license is {has_license}. Result: The person is authorized to drive.")
# else:
#     print("The person is not authorized to drive.")
#
# 9.	Write a Python program to convert user input from string to integer, float, and boolean types
# - Convert String to Integer in Python
#
# s = "42"
# num = int(s)
# print(num)
# - Convert String to Float in Python- s = '10.5674'
# f = float(s)
# print(type(f))
# print('Float Value =', f)
# - Convert String to Boolean in Python
# - s = "True"
# boolean_value = eval(s)
# print(boolean_value)
#
# 10.	Write code to demonstrate type casting with list elements.
# 11.	Write a program that checks if a number is positive, negative, or zero.
# 	number = float(input("Enter a number: "))
# if number > 0:
#     print("The number is positive.")
# elif number < 0:
#     print("The number is negative.")
# else:
#     print("The number is zero.")
#
# 12.	Write a for loop to print numbers from 1 to 10.
# 	for i in range(1, 11):
#     print(i)
#
# 13.	Write a Python program to find the sum of all even numbers between 1 and 50.
# 	total_sum = 0
# for number in range(1, 51):
#     if number % 2 == 0:
#        total_sum += number
# print(f"The sum of all even numbers between 1 and 50 is: {total_sum}")
#
# 14.	Write a program to reverse a string using a while loop
# 15.	Write a Python program to calculate the factorial of a number provided by the user using a while loop.
# 	def factorial(n):
#    num = 1
#    while n >= 1:
#    num = num * n
#    n = n - 1
#       return num
